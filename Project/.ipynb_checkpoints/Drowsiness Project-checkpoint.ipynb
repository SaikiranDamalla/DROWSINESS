# %% [markdown]
# # Project: Drowsiness Detection

# %% [markdown]
# ## Install Packages

# %%
# !pip3 install torch torchvision
# Out:
# Collecting torch
#   Using cached torch-2.11.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (29 kB)
# Collecting torchvision
#   Using cached torchvision-0.26.0-cp314-cp314-macosx_12_0_arm64.whl.metadata (5.5 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.env/lib/python3.14/site-packages (from torch) (4.15.0)
# Collecting setuptools<82 (from torch)
#   Using cached setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in ./.env/lib/python3.14/site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Using cached fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting numpy (from torchvision)
#   Using cached numpy-2.4.4-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Using cached pillow-12.2.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.14/site-packages (from jinja2->torch) (3.0.3)
# Using cached torch-2.11.0-cp314-cp314-macosx_11_0_arm64.whl (80.6 MB)
# Using cached setuptools-81.0.0-py3-none-any.whl (1.1 MB)
# Using cached torchvision-0.26.0-cp314-cp314-macosx_12_0_arm64.whl (1.9 MB)
# Using cached fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached pillow-12.2.0-cp314-cp314-macosx_11_0_arm64.whl (4.7 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached filelock-3.29.0-py3-none-any.whl (39 kB)
# Using cached numpy-2.4.4-cp314-cp314-macosx_14_0_arm64.whl (5.2 MB)
# Installing collected packages: mpmath, sympy, setuptools, pillow, numpy, networkx, fsspec, filelock, torch, torchvision
#   Attempting uninstall: setuptools5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/10 [sympy]
#     Found existing installation: setuptools 82.0.17m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/10 [sympy]
#     Uninstalling setuptools-82.0.1:m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/10 [sympy]
#       Successfully uninstalled setuptools-82.0.1m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/10 [setuptools]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [torchvision]m  9/10 [torchvision]
# Successfully installed filelock-3.29.0 fsspec-2026.4.0 mpmath-1.3.0 networkx-3.6.1 numpy-2.4.4 pillow-12.2.0 setuptools-81.0.0 sympy-1.14.0 torch-2.11.0 torchvision-0.26.0
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip3 install ultralytics labelme numpy albumentations matplotlib
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.4.48-py3-none-any.whl.metadata (39 kB)
# Collecting labelme
#   Using cached labelme-6.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in ./.env/lib/python3.14/site-packages (2.4.4)
# Collecting albumentations
#   Using cached albumentations-2.0.8-py3-none-any.whl.metadata (43 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp314-cp314-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Using cached opencv_python-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: pillow>=7.1.2 in ./.env/lib/python3.14/site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in ./.env/lib/python3.14/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in ./.env/lib/python3.14/site-packages (from ultralytics) (2.33.1)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Using cached scipy-1.17.1-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: torch>=1.8.0 in ./.env/lib/python3.14/site-packages (from ultralytics) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in ./.env/lib/python3.14/site-packages (from ultralytics) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in ./.env/lib/python3.14/site-packages (from ultralytics) (7.2.2)
# Collecting polars>=0.20.0 (from ultralytics)
#   Using cached polars-1.40.1-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Using cached ultralytics_thop-2.0.19-py3-none-any.whl.metadata (14 kB)
# Collecting imgviz>=2.0.0 (from labelme)
#   Using cached imgviz-2.0.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting loguru>=0.7 (from labelme)
#   Using cached loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting natsort>=7.1.0 (from labelme)
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting osam>=0.4.0 (from labelme)
#   Using cached osam-0.4.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting pyqt5>=5.14.0 (from labelme)
#   Using cached PyQt5-5.15.11-cp38-abi3-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting scikit-image>=0.21 (from labelme)
#   Using cached scikit_image-0.26.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting tifffile>=2024.1.30 (from labelme)
#   Using cached tifffile-2026.5.2-py3-none-any.whl.metadata (32 kB)
# Collecting pydantic>=2.9.2 (from albumentations)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting albucore==0.0.24 (from albumentations)
#   Using cached albucore-0.0.24-py3-none-any.whl.metadata (5.3 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations)
#   Using cached opencv_python_headless-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Collecting stringzilla>=3.10.4 (from albucore==0.0.24->albumentations)
#   Downloading stringzilla-4.6.1.tar.gz (646 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.5/646.5 kB 5.9 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting simsimd>=5.9.2 (from albucore==0.0.24->albumentations)
#   Using cached simsimd-6.5.16-cp314-cp314-macosx_11_0_arm64.whl.metadata (70 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.62.1-cp314-cp314-macosx_10_15_universal2.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in ./.env/lib/python3.14/site-packages (from matplotlib) (26.2)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./.env/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Collecting cmap>=0.1.0 (from imgviz>=2.0.0->labelme)
#   Using cached cmap-0.7.2-py3-none-any.whl.metadata (8.2 kB)
# Collecting click (from osam>=0.4.0->labelme)
#   Using cached click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting gdown>=6.0.0 (from osam>=0.4.0->labelme)
#   Using cached gdown-6.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting onnxruntime>=1.23.2 (from osam>=0.4.0->labelme)
#   Downloading onnxruntime-1.26.0-cp314-cp314-macosx_14_0_arm64.whl.metadata (5.3 kB)
# Requirement already satisfied: beautifulsoup4 in ./.env/lib/python3.14/site-packages (from gdown>=6.0.0->osam>=0.4.0->labelme) (4.14.3)
# Requirement already satisfied: filelock in ./.env/lib/python3.14/site-packages (from gdown>=6.0.0->osam>=0.4.0->labelme) (3.29.0)
# Collecting tqdm (from gdown>=6.0.0->osam>=0.4.0->labelme)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting flatbuffers (from onnxruntime>=1.23.2->osam>=0.4.0->labelme)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting protobuf (from onnxruntime>=1.23.2->osam>=0.4.0->labelme)
#   Using cached protobuf-7.34.1-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# Collecting polars-runtime-32==1.40.1 (from polars>=0.20.0->ultralytics)
#   Using cached polars_runtime_32-1.40.1-cp310-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.9.2->albumentations)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic>=2.9.2->albumentations)
#   Downloading pydantic_core-2.46.4-cp314-cp314-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in ./.env/lib/python3.14/site-packages (from pydantic>=2.9.2->albumentations) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.9.2->albumentations)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting PyQt5-sip<13,>=12.15 (from pyqt5>=5.14.0->labelme)
#   Using cached pyqt5_sip-12.18.0-cp314-cp314-macosx_10_15_universal2.whl.metadata (495 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from pyqt5>=5.14.0->labelme)
#   Using cached pyqt5_qt5-5.15.18-py3-none-macosx_11_0_arm64.whl.metadata (536 bytes)
# Requirement already satisfied: six>=1.5 in ./.env/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.env/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.env/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./.env/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2026.4.22)
# Requirement already satisfied: networkx>=3.0 in ./.env/lib/python3.14/site-packages (from scikit-image>=0.21->labelme) (3.6.1)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image>=0.21->labelme)
#   Using cached imageio-2.37.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting lazy-loader>=0.4 (from scikit-image>=0.21->labelme)
#   Using cached lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: setuptools<82 in ./.env/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in ./.env/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: jinja2 in ./.env/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in ./.env/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.env/lib/python3.14/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in ./.env/lib/python3.14/site-packages (from beautifulsoup4->gdown>=6.0.0->osam>=0.4.0->labelme) (2.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.14/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown>=6.0.0->osam>=0.4.0->labelme)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Using cached ultralytics-8.4.48-py3-none-any.whl (1.2 MB)
# Using cached labelme-6.2.0-py3-none-any.whl (589 kB)
# Using cached albumentations-2.0.8-py3-none-any.whl (369 kB)
# Using cached albucore-0.0.24-py3-none-any.whl (15 kB)
# Downloading matplotlib-3.10.9-cp314-cp314-macosx_11_0_arm64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 7.8 MB/s  0:00:017.8 MB/s eta 0:00:01:01
# Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (273 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.62.1-cp314-cp314-macosx_10_15_universal2.whl (2.9 MB)
# Using cached imgviz-2.0.0-py3-none-any.whl (7.9 MB)
# Using cached cmap-0.7.2-py3-none-any.whl (995 kB)
# Using cached kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl (64 kB)
# Using cached loguru-0.7.3-py3-none-any.whl (61 kB)
# Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Using cached opencv_python-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl (46.2 MB)
# Using cached opencv_python_headless-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl (46.2 MB)
# Using cached osam-0.4.0-py3-none-any.whl (2.2 MB)
# Using cached gdown-6.0.0-py3-none-any.whl (18 kB)
# Downloading onnxruntime-1.26.0-cp314-cp314-macosx_14_0_arm64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 6.9 MB/s  0:00:026.9 MB/s eta 0:00:01:01
# Using cached polars-1.40.1-py3-none-any.whl (828 kB)
# Using cached polars_runtime_32-1.40.1-cp310-abi3-macosx_11_0_arm64.whl (46.4 MB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp314-cp314-macosx_11_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.4 MB/s  0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached PyQt5-5.15.11-cp38-abi3-macosx_11_0_arm64.whl (6.6 MB)
# Using cached pyqt5_qt5-5.15.18-py3-none-macosx_11_0_arm64.whl (36.8 MB)
# Using cached pyqt5_sip-12.18.0-cp314-cp314-macosx_10_15_universal2.whl (124 kB)
# Using cached scikit_image-0.26.0-cp314-cp314-macosx_11_0_arm64.whl (12.1 MB)
# Using cached imageio-2.37.3-py3-none-any.whl (317 kB)
# Using cached lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Using cached scipy-1.17.1-cp314-cp314-macosx_14_0_arm64.whl (20.3 MB)
# Using cached simsimd-6.5.16-cp314-cp314-macosx_11_0_arm64.whl (94 kB)
# Using cached tifffile-2026.5.2-py3-none-any.whl (266 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached ultralytics_thop-2.0.19-py3-none-any.whl (28 kB)
# Using cached click-8.3.3-py3-none-any.whl (110 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached protobuf-7.34.1-cp310-abi3-macosx_10_9_universal2.whl (429 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Building wheels for collected packages: stringzilla
#   Building wheel for stringzilla (pyproject.toml) ... done
#   Created wheel for stringzilla: filename=stringzilla-4.6.1-cp314-cp314-macosx_15_0_arm64.whl size=200046 sha256=009154f7026574d13f799a82958432f656a062c708a90ebdb1bdd6ea45702cee
#   Stored in directory: /Users/rkg/Library/Caches/pip/wheels/2a/20/2d/f6c7dc5dd2597a88062f7a2d8b085bf132c67f951b7fcab55c
# Successfully built stringzilla
# Installing collected packages: simsimd, PyQt5-Qt5, flatbuffers, typing-inspection, tqdm, tifffile, stringzilla, scipy, PySocks, PyQt5-sip, pyparsing, pydantic-core, protobuf, polars-runtime-32, opencv-python-headless, opencv-python, natsort, loguru, lazy-loader, kiwisolver, imageio, fonttools, cycler, contourpy, cmap, click, annotated-types, scikit-image, pyqt5, pydantic, polars, onnxruntime, matplotlib, imgviz, albucore, ultralytics-thop, gdown, albumentations, ultralytics, osam, labelme
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41/41 [labelme]━ 38/41 [ultralytics]ns]ython]headless]
# Successfully installed PyQt5-Qt5-5.15.18 PyQt5-sip-12.18.0 PySocks-1.7.1 albucore-0.0.24 albumentations-2.0.8 annotated-types-0.7.0 click-8.3.3 cmap-0.7.2 contourpy-1.3.3 cycler-0.12.1 flatbuffers-25.12.19 fonttools-4.62.1 gdown-6.0.0 imageio-2.37.3 imgviz-2.0.0 kiwisolver-1.5.0 labelme-6.2.0 lazy-loader-0.5 loguru-0.7.3 matplotlib-3.10.9 natsort-8.4.0 onnxruntime-1.26.0 opencv-python-4.13.0.92 opencv-python-headless-4.13.0.92 osam-0.4.0 polars-1.40.1 polars-runtime-32-1.40.1 protobuf-7.34.1 pydantic-2.13.4 pydantic-core-2.46.4 pyparsing-3.3.2 pyqt5-5.15.11 scikit-image-0.26.0 scipy-1.17.1 simsimd-6.5.16 stringzilla-4.6.1 tifffile-2026.5.2 tqdm-4.67.3 typing-inspection-0.4.2 ultralytics-8.4.48 ultralytics-thop-2.0.19
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Import YOLO26

# %%
from ultralytics import YOLO
import os
import json
import uuid
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset_folder = 'dataset'

# %%
model = YOLO("yolo26n.pt")

# %%
img = os.path.join('test', 'test1.jpg')
results = model(img)
print(results)
# Out:
# image 1/1 /Users/rkg/Desktop/DROWSINESS/Project/test/test1.jpg: 640x640 1 person, 1 chair, 75.7ms
# Speed: 6.4ms preprocess, 75.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[209, 213, 214],
#         [209, 213, 214],
#         [209, 213, 214],
#         ...,
#         [207, 212, 213],
#         [207, 212, 213],
#         [207, 212, 213]],
#
#        [[209, 213, 214],
#         [209, 213, 214],
#         [209, 213, 214],
#         ...,
#         [207, 212, 213],
#         [207, 212, 213],
#         [207, 212, 213]],
#
#        [[209, 213, 214],
#         [209, 213, 214],
#         [209, 213, 214],
#         ...,
#         [207, 212, 213],
#         [207, 212, 213],
#         [207, 212, 213]],
#
#        ...,
#
#        [[ 74,  94, 105],
#         [ 74,  94, 105],
#         [ 73,  93, 104],
#         ...,
#         [ 73,  78,  77],
#         [ 64,  69,  68],
#         [ 57,  62,  61]],
#
#        [[ 80,  98, 109],
#         [ 80,  98, 109],
#         [ 79,  97, 108],
#         ...,
#         [ 73,  78,  77],
#         [ 65,  70,  69],
#         [ 58,  63,  62]],
#
#        [[ 83, 101, 112],
#         [ 83, 101, 112],
#         [ 82, 100, 111],
#         ...,
#         [ 74,  79,  78],
#         [ 66,  71,  70],
#         [ 59,  64,  63]]], shape=(1536, 1536, 3), dtype=uint8)
# orig_shape: (1536, 1536)
# path: '/Users/rkg/Desktop/DROWSINESS/Project/test/test1.jpg'
# probs: None
# save_dir: '/Users/rkg/Desktop/DROWSINESS/Project/runs/detect/predict'
# speed: {'preprocess': 6.385333021171391, 'inference': 75.71800000732765, 'postprocess': 2.6416670298203826}]

# %% [markdown]
# ## Dataset Pre-Processing

# %%
normal_path = os.path.join(dataset_folder, 'normal')
drowsy_path = os.path.join(dataset_folder, 'drowsy')
images_path = os.path.join(dataset_folder, 'images')

normal_images = os.listdir(normal_path)
drowsy_images = os.listdir(drowsy_path)

for normal_image in normal_images:
    print(os.path.join(normal_path, normal_image), os.path.join(images_path, 'normal.' + str(uuid.uuid1()) + '.png'))
    os.replace(os.path.join(normal_path, normal_image), os.path.join(images_path, 'normal.' + str(uuid.uuid1()) + '.png'))
    
for drowsy_image in drowsy_images:
    print(os.path.join(drowsy_path, drowsy_image), os.path.join(images_path, 'drowsy.' + str(uuid.uuid1()) + '.png'))
    os.replace(os.path.join(drowsy_path, drowsy_image), os.path.join(images_path, 'drowsy.' + str(uuid.uuid1()) + '.png'))

# %% [markdown]
# ## Labeling

# %%
# !labelme
# Out:
# 2026-05-10 19:27:47.503 | INFO     | labelme.__main__:main:230 - Starting Labelme 6.2.0
# qt.qpa.fonts: Populating font family aliases took 76 ms. Replace uses of missing font family "Monospace" with one that exists to avoid this cost.

# %% [markdown]
# Convert labelme coordinates to YOLO coordinates

# %%
def labelme_to_yolo(data):
    if data['shapes'][0]['label'] == "normal":
        label_class = 0
    else:
        label_class = 1

    image_width = data['imageWidth']
    image_height = data['imageHeight']
    
    x_min = data['shapes'][0]['points'][0][0]
    x_max = data['shapes'][0]['points'][1][0]
    y_min = data['shapes'][0]['points'][0][1]
    y_max = data['shapes'][0]['points'][1][1]

    x_center = (x_min + x_max) / 2
    y_center = (y_min + y_max) / 2

    bbox_width = x_max - x_min
    bbox_height = y_max - y_min
    
    return f'{label_class} {x_center/image_width} {y_center/image_height} {bbox_width/image_width} {bbox_height/image_height}'
    
    
    #print(x_min, x_max, y_min, y_max)
    #print(data['imageWidth'])
    #print(data['imageHeight'])

# %%
labels = os.listdir(os.path.join("dataset", "labels_labelme"))

for label in labels:
    with open(os.path.join("dataset", "labels_labelme", label), 'r', encoding='utf-8') as label_file:
        data = json.load(label_file)
        output = labelme_to_yolo(data)
    
    with open(os.path.join("dataset", "labels", f'{label.split('.json')[0]}.txt'), 'w', encoding='utf-8') as f:
        f.write(output)

# %% [markdown]
# ## Augmentation

# %%
import albumentations as alb

# %%
train_transform = alb.Compose([alb.HorizontalFlip(p=0.5),
                               alb.RGBShift(p=0.2),
                               alb.RandomBrightnessContrast(p=0.2),
                               alb.VerticalFlip(p=0.5),
                               alb.RandomGamma(p=0.2)
                              ], bbox_params=alb.BboxParams(format='yolo',
                              label_fields=['class_labels']
                             ))

# %%
total_aug = 20

for image in os.listdir(os.path.join(dataset_folder, 'images')):
    img = cv2.imread(os.path.join(dataset_folder, 'images', image))
    
    label_filepath = os.path.join(dataset_folder, 'labels', image.split(".png")[0] + '.txt')
    with open(label_filepath, 'r') as f:
        content = f.read()
    class_name = content.split(" ")[0]
    img_coords = np.array([content.split(" ")[1], content.split(" ")[2], content.split(" ")[3], content.split(" ")[4].split("\n")[0]], dtype=np.float32)

    try:
        for i in range(total_aug):
            aug_img = train_transform(image=img, bboxes=[img_coords], class_labels=[class_name])

            cv2.imwrite(os.path.join(dataset_folder, 'images', f'{image.split(".png")[0]}.{i}.jpg'), aug_img['image'])

            aug_content = f'{class_name} {aug_img["bboxes"][0][0]} {aug_img["bboxes"][0][1]} {aug_img["bboxes"][0][2]} {aug_img["bboxes"][0][3]}'
            with open(os.path.join(dataset_folder, 'labels', f'{image.split(".png")[0]}.{i}.txt'), 'w') as file:
                file.write(aug_content)

    except Exception as e:
        print(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 total_aug = 20
#       2
#       3 for image in os.listdir(os.path.join(dataset_folder, 'images')):
# ----> 4     img = cv2.imread(os.path.join(dataset_folder, 'images', image))
#       5
#       6     label_filepath = os.path.join(dataset_folder, 'labels', image.split(".png")[0] + '.txt')
#       7     with open(label_filepath, 'r') as f:
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# ## Training Model

# %%
results = model.train(data="dataset.yaml", epochs=100, imgsz=640)

# %% [markdown]
# ## Prediction

# %% [markdown]
# After total 7 experiments, most of them trained for 100 ephocs

# %%
model = YOLO(os.path.join("runs", "detect", "train7", "weights", "last.pt"))

# %%
results = model.predict(os.path.join('test', 'test1.jpg'))
results[0].show()
# Out:
# image 1/1 /Users/rkg/Desktop/DROWSINESS/Project/test/test1.jpg: 640x640 1 drowsy, 54.8ms
# Speed: 3.1ms preprocess, 54.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)

# %%
results = model.predict(os.path.join('test', 'test2.jpg'))
results[0].show()

# %%
results = model.predict(os.path.join('test', 'test3.jpg'))
results[0].show()
# Out:
# image 1/1 /Users/rkg/Desktop/DROWSINESS/Project/test/test3.jpg: 448x640 1 person, 1 car, 62.3ms
# Speed: 3.8ms preprocess, 62.3ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)

# %%
results = model.predict(os.path.join('test', 'test4.jpg'))
results[0].show()
# Out:
# image 1/1 /Users/rkg/Desktop/Project/test/test4.jpg: 384x640 1 normal, 41.3ms
# Speed: 3.7ms preprocess, 41.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)

# %%
results = model.predict(os.path.join('test', 'test5.jpg'))
results[0].show()
# Out:
# image 1/1 /Users/rkg/Desktop/Project/test/test5.jpg: 384x640 1 drowsy, 45.4ms
# Speed: 3.2ms preprocess, 45.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
